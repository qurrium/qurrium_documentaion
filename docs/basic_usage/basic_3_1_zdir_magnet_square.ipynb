# %% [markdown]
# # 3.1 Magnetization Square on Z Direction
#
# ---
#
# ## Basic Usage

# %% [markdown]
# ### a. Import the instances

# %%
from qurry import ZDirMagnetSquare

experiment_zdir_magnet_square = ZDirMagnetSquare()

# %% [markdown]
# ### b. Preparing quantum circuit

# %%
from qurry.recipe import trivial_paramagnet, ghz

# %%
circuits_dict = {
    "trivialPM_2": trivial_paramagnet(2),
    "trivialPM_4": trivial_paramagnet(4),
    "trivialPM_6": trivial_paramagnet(6),
    "trivialPM_8": trivial_paramagnet(8),
    "cat_2": ghz(2),
    "cat_4": ghz(4),
    "cat_6": ghz(6),
    "cat_8": ghz(8),
}
print("| trivial paramagnet and cat in 4 qubits:")
print(circuits_dict["trivialPM_4"])
print(circuits_dict["cat_4"])
# Out:
# | trivial paramagnet and cat in 4 qubits:
#      ┌───┐
# q_0: ┤ H ├
#      ├───┤
# q_1: ┤ H ├
#      ├───┤
# q_2: ┤ H ├
#      ├───┤
# q_3: ┤ H ├
#      └───┘
#      ┌───┐
# q_0: ┤ H ├──■────────────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■───────
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├──■──
#                └───┘┌─┴─┐
# q_3: ───────────────┤ X ├
#                     └───┘

# %% [markdown]
# ### c. Execute the circuit

# %% [markdown]
# #### i. Directly input the circuit
#
# After executing, it will return a uuid of experiment. You can use this uuid to get the result of the experiment.

# %%
exp1 = experiment_zdir_magnet_square.measure(circuits_dict["cat_6"], shots=4096)
exp1
# Out:
# <ZMSExperiment(
#   exp_id='fb8c5076-c89b-4f5f-9236-66222af14df6',
#   args=ZMSArguments(exp_name='experiment.magnet_square_z', num_qubits=6),
#   commons=Commonparams(exp_id='fb8c5076-c89b-4f5f-9236-66222af14df6', target_keys=[0], shots=4096, backend=<AerSimulator('aer_simulator')>, run_args={}, transpile_args={}, tags=(), save_location=PosixPath('.'), serial=None, summoner_id=None, summoner_name=None, datetimes=DatetimeDict({'build': '2026-04-01 18:34:55', 'run.001': '2026-04-01 18:34:55'}), folder=None),
#   unused_args_num=0,
#   analysis_num=1)>

# %% [markdown]
# Each experiment result will be stored in a container `.exps`, which you can access later by the uuid of the experiment. For example, you can access the result of `exp1` by `experiment_zdir_magnet_square.exps[exp1.exp_id]`.

# %%
print("| The exp_id:", exp1.exp_id)
experiment_zdir_magnet_square.exps[exp1.exp_id]
# Out:
# | The exp_id: fb8c5076-c89b-4f5f-9236-66222af14df6
# <ZMSExperiment(
#   exp_id='fb8c5076-c89b-4f5f-9236-66222af14df6',
#   args=ZMSArguments(exp_name='experiment.magnet_square_z', num_qubits=6),
#   commons=Commonparams(exp_id='fb8c5076-c89b-4f5f-9236-66222af14df6', target_keys=[0], shots=4096, backend=<AerSimulator('aer_simulator')>, run_args={}, transpile_args={}, tags=(), save_location=PosixPath('.'), serial=None, summoner_id=None, summoner_name=None, datetimes=DatetimeDict({'build': '2026-04-01 18:34:55', 'run.001': '2026-04-01 18:34:55'}), folder=None),
#   unused_args_num=0,
#   analysis_num=1)>

# %% [markdown]
# For `ZDirMagnetSquare`, its `.analyze` does not require any arguments, so its post-processing will be executed automatically after `.measure`.

# %%
exp1.reports
# Out:
# AnalysesContainer(length=1, {
#   0: <ZMSAnalysis(serial=0, ZMSProcessEntries(shots=4096, num_qubits=6), unused_args_num=0)})

# %%
report01 = exp1.reports[0]
report01
# Out:
# <ZMSAnalysis(serial=0, ZMSProcessEntries(shots=4096, num_qubits=6), unused_args_num=0)

# %%
report01.results_fields()
# Out:
# (('default', 'magnet_square'),
#  ('default', 'magnet_square_cells'),
#  ('default', 'taking_time'))

# %%
report01.results
# Out:
# {'default': ZMSDefaultResult(magnet_square=1.0, magnet_square_cells={14: 1.0, 20: 1.0, 12: 1.0, 6: 1.0, 25: 1.0, 24: 1.0, 1: 1.0, 8: 1.0, 13: 1.0, 18: 1.0, 11: 1.0, 10: 1.0, 4: 1.0, 19: 1.0, 16: 1.0, 28: 1.0, 21: 1.0, 27: 1.0, 17: 1.0, 22: 1.0, 5: 1.0, 15: 1.0, 26: 1.0, 3: 1.0, 23: 1.0, 29: 1.0, 7: 1.0, 2: 1.0, 0: 1.0, 9: 1.0}, taking_time=0.000373217)}

# %%
print("| The purity:")
print(report01["default", "magnet_square"])
# or
print(report01.results["default"].magnet_square)
# Out:
# | The purity:
# 1.0
# 1.0

# %% [markdown]
# #### ii. Add the circuits to container `.waves`, then call them later.
#
# Since we have executed an experiment, the circuit we input in `exp1` is stored in the container `.waves` with serial number `0`.

# %%
experiment_zdir_magnet_square.waves
# Out:
# WaveContainer(num=1, {
#   0: <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580bbc0>})

# %% [markdown]
# But we can also add the circuit to the container `.waves` with a custom name.
# The name should be unique, otherwise it will be overwritten.
# The method `add` will return the actual name of the circuit in the container.

# %%
for k, v in circuits_dict.items():
    key_of_cirq = experiment_zdir_magnet_square.add(v, k)
    print(f"| {k} added with key: {key_of_cirq}")
print(experiment_zdir_magnet_square.waves["cat_4"])
# Out:
# | trivialPM_2 added with key: trivialPM_2
# | trivialPM_4 added with key: trivialPM_4
# | trivialPM_6 added with key: trivialPM_6
# | trivialPM_8 added with key: trivialPM_8
# | cat_2 added with key: cat_2
# | cat_4 added with key: cat_4
# | cat_6 added with key: cat_6
# | cat_8 added with key: cat_8
#      ┌───┐
# q_0: ┤ H ├──■────────────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■───────
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├──■──
#                └───┘┌─┴─┐
# q_3: ───────────────┤ X ├
#                     └───┘

# %% [markdown]
# If there is a circuit with the same name, it will be replaced by the new one.

# %%
print(experiment_zdir_magnet_square.add(circuits_dict["cat_4"], "cat_4"))
print(experiment_zdir_magnet_square.waves["cat_4"])
# Out:
# cat_4
#      ┌───┐
# q_0: ┤ H ├──■────────────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■───────
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├──■──
#                └───┘┌─┴─┐
# q_3: ───────────────┤ X ├
#                     └───┘

# %% [markdown]
# Otherwise, you will need to use `replace="duplicate"` to prevent it from being replaced.

# %%
duplicated_case01 = experiment_zdir_magnet_square.add(
    circuits_dict["cat_4"], "cat_4", replace="duplicate"
)
print(duplicated_case01)
print(experiment_zdir_magnet_square.waves[duplicated_case01])
# Out:
# cat_4.9
#      ┌───┐
# q_0: ┤ H ├──■────────────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■───────
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├──■──
#                └───┘┌─┴─┐
# q_3: ───────────────┤ X ├
#                     └───┘

# %% [markdown]
# Now we have prepared the circuit and stored it in the container `.waves`.

# %%
experiment_zdir_magnet_square.waves
# Out:
# WaveContainer(num=10, {
#   0: <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580bbc0>,
#   'trivialPM_2': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580b830>,
#   'trivialPM_4': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x7906e485f3b0>,
#   'trivialPM_6': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580b980>,
#   'trivialPM_8': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580b9e0>,
#   'cat_2': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580baa0>,
#   'cat_4': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580bb30>,
#   'cat_6': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580bbc0>,
#   'cat_8': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580bc80>,
#   'cat_4.9': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x79062580bb30>})

# %% [markdown]
# Finally, we can execute the circuit and get the result.

# %%
exp2 = experiment_zdir_magnet_square.measure("cat_4", shots=4096)
exp2
# Out:
# <ZMSExperiment(
#   exp_id='4bf68f44-bf44-4ac5-880a-c68f13bb5255',
#   args=ZMSArguments(exp_name='experiment.magnet_square_z', num_qubits=4),
#   commons=Commonparams(exp_id='4bf68f44-bf44-4ac5-880a-c68f13bb5255', target_keys=['cat_4'], shots=4096, backend=<AerSimulator('aer_simulator')>, run_args={}, transpile_args={}, tags=(), save_location=PosixPath('.'), serial=None, summoner_id=None, summoner_name=None, datetimes=DatetimeDict({'build': '2026-04-01 18:37:51', 'run.001': '2026-04-01 18:37:51'}), folder=None),
#   unused_args_num=0,
#   analysis_num=1)>

# %%
report02 = exp2.reports[0]
report02
# Out:
# <ZMSAnalysis(serial=0, ZMSProcessEntries(shots=4096, num_qubits=4), unused_args_num=0)

# %% [markdown]
# ### d. Export them after all

# %%
exp1_id, exp1_files_info = exp1.write(
    save_location=".",  # where to save files
)
exp1_files_info
# Out:
# {'save_location': '.',
#  'folder': 'experiment.magnet_square_z.001',
#  'qurryinfo': 'experiment.magnet_square_z.001/qurryinfo.json',
#  'args': 'experiment.magnet_square_z.001/args/id=fb8c5076-c89b-4f5f-9236-66222af14df6.args.json',
#  'advent': 'experiment.magnet_square_z.001/advent/id=fb8c5076-c89b-4f5f-9236-66222af14df6.advent.json',
#  'legacy': 'experiment.magnet_square_z.001/legacy/id=fb8c5076-c89b-4f5f-9236-66222af14df6.legacy.json',
#  'tales': 'experiment.magnet_square_z.001/tales/id=fb8c5076-c89b-4f5f-9236-66222af14df6.tales.json',
#  'myths': 'experiment.magnet_square_z.001/myths/id=fb8c5076-c89b-4f5f-9236-66222af14df6.myths.json'}

# %% [markdown]
# ### f. Read the saved results

# %%
read_result_new = experiment_zdir_magnet_square.read(
    "experiment.magnet_square_z.001",
    save_location=".",  # where files are saved
)
read_result_new
# Out:
# {'fb8c5076-c89b-4f5f-9236-66222af14df6': <ZMSExperiment(
#    exp_id='fb8c5076-c89b-4f5f-9236-66222af14df6',
#    args=ZMSArguments(exp_name='experiment.magnet_square_z', num_qubits=6),
#    commons=Commonparams(exp_id='fb8c5076-c89b-4f5f-9236-66222af14df6', target_keys=[0], shots=4096, backend='aer_simulator', run_args={}, transpile_args={}, tags=(), save_location='.', serial=None, summoner_id=None, summoner_name=None, datetimes=DatetimeDict({'build': '2026-04-01 18:34:55', 'run.001': '2026-04-01 18:34:55'}), folder='experiment.magnet_square_z.001'),
#    unused_args_num=0,
#    analysis_num=1)>}

# %% [markdown]
# ## Post-Process Availablities and Version Info

# %%
from qurry.process import AVAIBILITY_STATESHEET

AVAIBILITY_STATESHEET
# Out:
#  | Qurrium version: 1.0.0.dev2
# ---------------------------------------------------------------------------
#  ### Qurrium Post-Processing
#    - Backend Availability ................... Python Cython Rust   JAX
#  - randomized_measure
#    - entangled_entropy.entropy_core_2 ....... Yes    No     Yes    No
#    - entangled_entropy_v1.entropy_core ...... Yes    Depr.  Yes    No
#    - wavefunction_overlap.echo_core_2 ....... Yes    No     Yes    No
#    - wavefunction_overlap_v1.echo_core ...... Yes    Depr.  Yes    No
#  - hadamard_test
#    - purity_echo_core ....................... Yes    No     Yes    No
#  - magnet_square
#    - magnsq_core ............................ Yes    No     Yes    No
#  - string_operator
#    - strop_core ............................. Yes    No     Yes    No
#  - classical_shadow
#    - rho_process ............................ Yes    No     Yes    No
#    - matrix_calculation ..................... Yes    No     No     Yes
#  - utils
#    - randomized ............................. Yes    Depr.  Yes    No
#    - counts_process ......................... Yes    No     Yes    No
#    - bit_slice .............................. Yes    No     Yes    No
#    - dummy .................................. Yes    No     Yes    No
# ---------------------------------------------------------------------------
#    + Yes ...... Working normally.
#    + Error .... Exception occurred.
#    + No ....... Not supported.
#    + Depr. .... Deprecated.
# ---------------------------------------------------------------------------
# by <Hoshi>
