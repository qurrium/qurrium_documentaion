# %% [markdown]
# # 1.1 Entanglement Entropy by Hadamard Test
#
# ---
#
# ## Basic Usage

# %% [markdown]
# ### a. Import the instances

# %%
from qurry import EntropyMeasure

experiment_hadamard = EntropyMeasure(method="hadamard")

# %% [markdown]
# ### b. Preparing quantum circuit

# %%
from qiskit import QuantumCircuit
from qurry.recipe import trivial_paramagnet, ghz

# %%
sample01 = trivial_paramagnet(8)
print("| trivial paramagnet in 8 qubits:")
print(sample01)
# Out:
# | trivial paramagnet in 8 qubits:
#      ┌───┐
# q_0: ┤ H ├
#      ├───┤
# q_1: ┤ H ├
#      ├───┤
# q_2: ┤ H ├
#      ├───┤
# q_3: ┤ H ├
#      ├───┤
# q_4: ┤ H ├
#      ├───┤
# q_5: ┤ H ├
#      ├───┤
# q_6: ┤ H ├
#      ├───┤
# q_7: ┤ H ├
#      └───┘

# %%
sample02 = ghz(8)
print("| GHZ in 8 qubits:")
print(sample02)
# Out:
# | GHZ in 8 qubits:
#      ┌───┐
# q_0: ┤ H ├──■────────────────────────────────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■───────────────────────────
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├──■──────────────────────
#                └───┘┌─┴─┐
# q_3: ───────────────┤ X ├──■─────────────────
#                     └───┘┌─┴─┐
# q_4: ────────────────────┤ X ├──■────────────
#                          └───┘┌─┴─┐
# q_5: ─────────────────────────┤ X ├──■───────
#                               └───┘┌─┴─┐
# q_6: ──────────────────────────────┤ X ├──■──
#                                    └───┘┌─┴─┐
# q_7: ───────────────────────────────────┤ X ├
#                                         └───┘

# %%
sample03 = QuantumCircuit(8)
sample03.x(range(0, 8, 2))
print("| Custom circuit:")
print(sample03)
# Out:
# | Custom circuit:
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘
# q_3: ─────
#      ┌───┐
# q_4: ┤ X ├
#      └───┘
# q_5: ─────
#      ┌───┐
# q_6: ┤ X ├
#      └───┘
# q_7: ─────

# %% [markdown]
# ### c. Execute the circuit

# %% [markdown]
# #### i. Directly input the circuit
#
# After executing, it will return a uuid of experiment. You can use this uuid to get the result of the experiment.

# %%
exp1 = experiment_hadamard.measure(sample01, degree=4, shots=4096)
exp1
# Out:
# <EMHExperiment(
#   exp_id='80846e22-dbc1-4e18-8932-efbc98190d82',
#   args=EMHArguments(exp_name='experiment.entropy_hadamard', degree=(4, 8)),
#   commons=Commonparams(exp_id='80846e22-dbc1-4e18-8932-efbc98190d82', target_keys=[0], shots=4096, backend=<AerSimulator('aer_simulator')>, run_args={}, transpile_args={}, tags=(), save_location=PosixPath('.'), serial=None, summoner_id=None, summoner_name=None, datetimes=DatetimeDict({'build': '2026-04-01 17:21:18', 'run.001': '2026-04-01 17:21:18'}), folder=None),
#   unused_args_num=0,
#   analysis_num=1)>

# %% [markdown]
# Each experiment result will be stored in a container `.exps`, which you can access later by the uuid of the experiment. For example, you can access the result of `exp1` by `experiment_hadamard.exps[exp1.exp_id]`.

# %%
print("| The exp_id:", exp1.exp_id)
experiment_hadamard.exps[exp1.exp_id]
# Out:
# | The exp_id: 80846e22-dbc1-4e18-8932-efbc98190d82
# <EMHExperiment(
#   exp_id='80846e22-dbc1-4e18-8932-efbc98190d82',
#   args=EMHArguments(exp_name='experiment.entropy_hadamard', degree=(4, 8)),
#   commons=Commonparams(exp_id='80846e22-dbc1-4e18-8932-efbc98190d82', target_keys=[0], shots=4096, backend=<AerSimulator('aer_simulator')>, run_args={}, transpile_args={}, tags=(), save_location=PosixPath('.'), serial=None, summoner_id=None, summoner_name=None, datetimes=DatetimeDict({'build': '2026-04-01 17:21:18', 'run.001': '2026-04-01 17:21:18'}), folder=None),
#   unused_args_num=0,
#   analysis_num=1)>

# %% [markdown]
# For `EntropyMeasure(method="hadamard")`, its `.analyze` does not require any arguments, so its post-processing will be executed automatically after `.measure`.

# %%
exp1.reports
# Out:
# AnalysesContainer(length=1, {
#   0: <EMHAnalysis(serial=0, EMHProcessEntries(shots=4096), unused_args_num=0)})

# %%
report01 = exp1.reports[0]
report01
# Out:
# <EMHAnalysis(serial=0, EMHProcessEntries(shots=4096), unused_args_num=0)

# %%
report01.results_fields()
# Out:
# (('default', 'purity'), ('default', 'entropy'))

# %%
report01.results
# Out:
# {'default': EMHDefaultResults(purity=1.0, entropy=-0.0)}

# %%
print("| The purity:")
print(report01["default", "purity"])
# or
print(report01.results["default"].purity)
# Out:
# | The purity:
# 1.0
# 1.0

# %% [markdown]
# #### ii. Add the circuits to container `.waves`, then call them later.
#
# Since we have executed an experiment, the circuit we input in `exp1` is stored in the container `.waves` with serial number `0`.

# %%
experiment_hadamard.waves
# Out:
# WaveContainer(num=1, {
#   0: <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x793edc4e0920>})

# %% [markdown]
# But we can also add the circuit to the container `.waves` with a custom name.
# The name should be unique, otherwise it will be overwritten.
# The method `add` will return the actual name of the circuit in the container.

# %%
print(experiment_hadamard.add(sample02, "ghz_8"))
print(experiment_hadamard.waves["ghz_8"])
# Out:
# ghz_8
#      ┌───┐
# q_0: ┤ H ├──■────────────────────────────────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■───────────────────────────
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├──■──────────────────────
#                └───┘┌─┴─┐
# q_3: ───────────────┤ X ├──■─────────────────
#                     └───┘┌─┴─┐
# q_4: ────────────────────┤ X ├──■────────────
#                          └───┘┌─┴─┐
# q_5: ─────────────────────────┤ X ├──■───────
#                               └───┘┌─┴─┐
# q_6: ──────────────────────────────┤ X ├──■──
#                                    └───┘┌─┴─┐
# q_7: ───────────────────────────────────┤ X ├
#                                         └───┘

# %% [markdown]
# If there is a circuit with the same name, it will be replaced by the new one.

# %%
print(experiment_hadamard.add(sample03, "ghz_8"))
print(experiment_hadamard.waves["ghz_8"])
# Out:
# ghz_8
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘
# q_3: ─────
#      ┌───┐
# q_4: ┤ X ├
#      └───┘
# q_5: ─────
#      ┌───┐
# q_6: ┤ X ├
#      └───┘
# q_7: ─────

# %% [markdown]
# Otherwise, you will need to use `replace="duplicate"` to prevent it from being replaced.

# %%
duplicated_case01 = experiment_hadamard.add(sample02, "ghz_8", replace="duplicate")
print(duplicated_case01)
print(experiment_hadamard.waves[duplicated_case01])
# Out:
# ghz_8.2
#      ┌───┐
# q_0: ┤ H ├──■────────────────────────────────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■───────────────────────────
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├──■──────────────────────
#                └───┘┌─┴─┐
# q_3: ───────────────┤ X ├──■─────────────────
#                     └───┘┌─┴─┐
# q_4: ────────────────────┤ X ├──■────────────
#                          └───┘┌─┴─┐
# q_5: ─────────────────────────┤ X ├──■───────
#                               └───┘┌─┴─┐
# q_6: ──────────────────────────────┤ X ├──■──
#                                    └───┘┌─┴─┐
# q_7: ───────────────────────────────────┤ X ├
#                                         └───┘

# %% [markdown]
# Now we have prepared the circuit and stored it in the container `.waves`.

# %%
experiment_hadamard.waves
# Out:
# WaveContainer(num=3, {
#   0: <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x793edc4e0920>,
#   'ghz_8': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x793edc49f230>,
#   'ghz_8.2': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x793edc4e1220>})

# %% [markdown]
# Finally, we can execute the circuit and get the result.

# %%
exp2 = experiment_hadamard.measure("ghz_8.2", degree=4, shots=4096)
exp2
# Out:
# <EMHExperiment(
#   exp_id='c67ca474-4bae-4aec-8808-a4e7175ea5a2',
#   args=EMHArguments(exp_name='experiment.entropy_hadamard', degree=(4, 8)),
#   commons=Commonparams(exp_id='c67ca474-4bae-4aec-8808-a4e7175ea5a2', target_keys=['ghz_8.2'], shots=4096, backend=<AerSimulator('aer_simulator')>, run_args={}, transpile_args={}, tags=(), save_location=PosixPath('.'), serial=None, summoner_id=None, summoner_name=None, datetimes=DatetimeDict({'build': '2026-04-01 17:21:28', 'run.001': '2026-04-01 17:21:28'}), folder=None),
#   unused_args_num=0,
#   analysis_num=1)>

# %%
exp2
# Out:
# <EMHExperiment(
#   exp_id='c67ca474-4bae-4aec-8808-a4e7175ea5a2',
#   args=EMHArguments(exp_name='experiment.entropy_hadamard', degree=(4, 8)),
#   commons=Commonparams(exp_id='c67ca474-4bae-4aec-8808-a4e7175ea5a2', target_keys=['ghz_8.2'], shots=4096, backend=<AerSimulator('aer_simulator')>, run_args={}, transpile_args={}, tags=(), save_location=PosixPath('.'), serial=None, summoner_id=None, summoner_name=None, datetimes=DatetimeDict({'build': '2026-04-01 17:21:28', 'run.001': '2026-04-01 17:21:28'}), folder=None),
#   unused_args_num=0,
#   analysis_num=1)>

# %%
report02 = exp2.analyze()
report02
# Out:
# <EMHAnalysis(serial=1, EMHProcessEntries(shots=4096), unused_args_num=0)

# %% [markdown]
# ### d. Export them after all

# %%
exp1_id, exp1_files_info = exp1.write(
    save_location=".",  # where to save files
)
exp1_files_info
# Out:
# {'save_location': '.',
#  'folder': 'experiment.entropy_hadamard.001',
#  'qurryinfo': 'experiment.entropy_hadamard.001/qurryinfo.json',
#  'args': 'experiment.entropy_hadamard.001/args/id=80846e22-dbc1-4e18-8932-efbc98190d82.args.json',
#  'advent': 'experiment.entropy_hadamard.001/advent/id=80846e22-dbc1-4e18-8932-efbc98190d82.advent.json',
#  'legacy': 'experiment.entropy_hadamard.001/legacy/id=80846e22-dbc1-4e18-8932-efbc98190d82.legacy.json',
#  'tales': 'experiment.entropy_hadamard.001/tales/id=80846e22-dbc1-4e18-8932-efbc98190d82.tales.json',
#  'myths': 'experiment.entropy_hadamard.001/myths/id=80846e22-dbc1-4e18-8932-efbc98190d82.myths.json'}

# %% [markdown]
# ### f. Read the saved results

# %%
read_results = experiment_hadamard.read(
    "experiment.entropy_hadamard.001",
    save_location=".",  # where files are saved
)
read_results
# Out:
# {'80846e22-dbc1-4e18-8932-efbc98190d82': <EMHExperiment(
#    exp_id='80846e22-dbc1-4e18-8932-efbc98190d82',
#    args=EMHArguments(exp_name='experiment.entropy_hadamard', degree=(4, 8)),
#    commons=Commonparams(exp_id='80846e22-dbc1-4e18-8932-efbc98190d82', target_keys=[0], shots=4096, backend='aer_simulator', run_args={}, transpile_args={}, tags=(), save_location='.', serial=None, summoner_id=None, summoner_name=None, datetimes=DatetimeDict({'build': '2026-04-01 17:21:18', 'run.001': '2026-04-01 17:21:18'}), folder='experiment.entropy_hadamard.001'),
#    unused_args_num=0,
#    analysis_num=1)>}

# %% [markdown]
# ## Post-Process Availablities and Version Info

# %%
from qurry.process import AVAIBILITY_STATESHEET

AVAIBILITY_STATESHEET
# Out:
#  | Qurrium version: 1.0.0.dev2
# ---------------------------------------------------------------------------
#  ### Qurrium Post-Processing
#    - Backend Availability ................... Python Cython Rust   JAX
#  - randomized_measure
#    - entangled_entropy.entropy_core_2 ....... Yes    No     Yes    No
#    - entangled_entropy_v1.entropy_core ...... Yes    Depr.  Yes    No
#    - wavefunction_overlap.echo_core_2 ....... Yes    No     Yes    No
#    - wavefunction_overlap_v1.echo_core ...... Yes    Depr.  Yes    No
#  - hadamard_test
#    - purity_echo_core ....................... Yes    No     Yes    No
#  - magnet_square
#    - magnsq_core ............................ Yes    No     Yes    No
#  - string_operator
#    - strop_core ............................. Yes    No     Yes    No
#  - classical_shadow
#    - rho_process ............................ Yes    No     Yes    No
#    - matrix_calculation ..................... Yes    No     No     Yes
#  - utils
#    - randomized ............................. Yes    Depr.  Yes    No
#    - counts_process ......................... Yes    No     Yes    No
#    - bit_slice .............................. Yes    No     Yes    No
#    - dummy .................................. Yes    No     Yes    No
# ---------------------------------------------------------------------------
#    + Yes ...... Working normally.
#    + Error .... Exception occurred.
#    + No ....... Not supported.
#    + Depr. .... Deprecated.
# ---------------------------------------------------------------------------
# by <Hoshi>
